# %% [markdown]
# <a href="https://colab.research.google.com/github/Espinosa-Ventura-Zeus-Gerardo/zeus/blob/main/INTRODUCTION_TO_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UNIVERSIDAD TECNOLOGICA DE ALTAMIRA
#
# MEC3C Probability and Statistics
#
# Espinosa Venntura Zeus Gerardo.
# 492010288
#
# 492010288@utaltamira.edu.mx
#
# Teacher: Jesus Rafael Dominguez Torres

# %% [markdown]
# #INTRODUCTION TO PYTHON
# *History of Python
#
# *Print statement
#
# *If-else statement
#
# *Loops

# %% [markdown]
# ## what is Python?

# %% [markdown]
# Python is a type of high-level programming language that is easy to use and open source with endless uses. It became popular due to the simple syntax when programming and thanks to being friendly with users.

# %% [markdown]
# In 1989, Guido Van Rossum gave continuity to the ABC programming language in which he had worked at Centrum Wiskunde and Informatica (CWI).
# This language is focused on being easy for users to use and learn and his project started as a hobby of Rossum.
# The name Python has its origins in Rossum's affiliation with the Monty Python group.

# %% [markdown]
# ![phyton (1).png](data:image/png;base64,...)

# %% [markdown]
# The language was finally released in 1991. When it was released, it used a lot fewer codes to express the concepts, when we compare it with Java, C++ & C.

# %% [markdown]
# Release date of the different versions of Python
#
# *  Python 1.0; January 1994
# *  Python 1.5;	December 31, 1997
# *  Python 1.6;	September 5, 2000
# *  Python 2.0;	October 16, 2000
# *  Python 2.1;	April 17, 2001
# *  Python 2.2;	December 21, 2001
# *  Python 2.3;	July 29, 2003
# *  Python 2.4;	November 30, 2004
# *  Python 2.5;	September 19, 2006
# *  Python 2.6;	October 1, 2008
# *  Python 2.7;	July 3, 2010
# *  Python 3.0;	December 3, 2008
# *  Python 3.1;	June 27, 2009
# *  Python 3.2;	February 20, 2011
# *  Python 3.3;	September 29, 2012
# *  Python 3.4;	March 16, 2014
# *  Python 3.5;	September 13, 2015
# *  Python 3.6;	December 23, 2016
# *  Python 3.7;	June 27, 2018
# *  Python 3.8;	October 14, 2019

# %% [markdown]
# ## Print statement

# %% [markdown]
# The PRINT statement sends data to the display terminal or to another specified print unit.The PRINTER statement determines the output device to which data will be written by the PRINT statement.
#
# The function of the PRINT statement is to instruct the computer to output something, either on the terminal or the printer. It can be used in several different ways.

# %% [markdown]
# *In the following image, we can see an example of a Print statement in Python*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("example of a Print statement Python" )
# Out:
# example of a Print statement Python

# %%
print("my name is ZEUS")
# Out:
# my name is ZEUS

# %%
a=15
b=20
c=3
print(a+b*c)
# Out:
# 75

# %% [markdown]
# ## If-else statement

# %% [markdown]
# The if/else statement extends the if statement by specifying an action if the if (true/false expression) is false.
#
#
# With the if statement, a program will execute the true code block or do nothing. With the if/else statement, the program will execute either the true code block or the false code block so something is always executed with an if/else statement.

# %% [markdown]
# *In the following image, we can see an example of If-else statement in Python*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
y = 3

if y > 4:
  print("¡true!")
else:
  print("¡false!")
# Out:
# ¡false!

# %% [markdown]
# ## Loops

# %% [markdown]
# A Python for loop iterates over an object until that object is complete. For instance, you can iterate over the contents of a list or a string. The for loop uses the syntax: for item in object, where “object” is the iterable over which you want to iterate.

# %% [markdown]
# A Python for loop runs a block of code until the loop has iterated over every item in an iterable. For loops help you reduce repetition in your code because they let you execute the same operation multiple times.

# %% [markdown]
# *In the following image, we can see an example of loops in Python*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def longitud(mi_lista):
    cont = 0
    for _ in mi_lista:
        cont += 1
    return cont

# %% [markdown]
# ## bibliography

# %% [markdown]
# --(06 May, 2019)
#
# https://www.geeksforgeeks.org/history-of-python/
# (History of Python - GeeksforGeeks)
#
# --https://www.javatpoint.com/python-history
# (Python History and Versions - Javatpoint)
#
# --https://www3.rocketsoftware.com/rocketd3/support/documentation/mvb/32/refman/mvbasic/print_statement.htm
# (PRINT Statement - Rocket Software)
#
# --https://eecs.oregonstate.edu/ecampus-video/CS161/template/chapter_4/ifelse.html(Chapter 4: The if/else (if) statement and Nested statements)
#
#
# --JAMES GALLAGHER (10 dic. 2020 )
#
# https://careerkarma.com/blog/python-for-loop/
# (Python for Loop: The Complete Guide | Career Karma)
#
# --OxfordUnion (30 dic 2019)
#
# https://www.youtube.com/watch?v=7kn7NtlV6g0
# (Creator of Python Programming Language, Guido van Rossum | Oxford Union) video
